# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\Wealth\Downloads\Task-01.csv")

# %%
totalpopulation_df = pd.read_csv(r"C:\Users\Wealth\Downloads\Task-01.csv")

# %%
df.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2014         2015         2016         2017  \
# ...

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023'],
#       dtype='object')

# %%
df.shape
# Out:
# (266, 68)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 68 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            264 non-null    float64
#  5   1961            264 non-null    float64
#  6   1962            264 non-null    float64
#  7   1963            264 non-null    float64
#  8   1964            264 non-null    float64
#  9   1965            264 non-null    float64
#  10  1966            264 non-null    float64
#  11  1967            264 non-null    float64
#  12  1968            264 non-null    float64
#  13  1969            264 non-null    float64
#  14  1970            264 non-null    float64
#  15  1971            264 non-null    float64
#  16  1972            264 non-null    float64
# ...

# %%
totalpopulation_sort=totalpopulation_df.sort_values(by='2020',ascending=False)
print(totalpopulation_sort['2020'])
# Out:
# 259    7.820206e+09
# 103    6.627317e+09
# 140    6.549996e+09
# 156    5.882943e+09
# 102    4.867092e+09
#            ...
# 255    3.091000e+04
# 188    1.797200e+04
# 179    1.231500e+04
# 245    1.106900e+04
# 110             NaN
# Name: 2020, Length: 266, dtype: float64

# %%
top30_countries=totalpopulation_sort.head(30)
print(top30_countries)
# Out:
#                                      Country Name Country Code  \
# 259                                         World          WLD
# 103                              IDA & IBRD total          IBT
# 140                           Low & middle income          LMY
# 156                                 Middle income          MIC
# 102                                     IBRD only          IBD
# 62                     Early-demographic dividend          EAR
# 139                           Lower middle income          LMC
# 249                           Upper middle income          UMC
# 63                            East Asia & Pacific          EAS
# 142                     Late-demographic dividend          LTE
# 61    East Asia & Pacific (excluding high income)          EAP
# 230    East Asia & Pacific (IDA & IBRD countries)          TEA
# 240                       South Asia (IDA & IBRD)          TSA
# 204                                    South Asia          SAS
# ...

# %%
totalpopulation_sort_2020=totalpopulation_df.sort_values(by='2020',ascending=False)
top30_countries_2020=totalpopulation_sort_2020.head(30)
print(top30_countries_2020)
# Out:
#                                      Country Name Country Code  \
# 259                                         World          WLD
# 103                              IDA & IBRD total          IBT
# 140                           Low & middle income          LMY
# 156                                 Middle income          MIC
# 102                                     IBRD only          IBD
# 62                     Early-demographic dividend          EAR
# 139                           Lower middle income          LMC
# 249                           Upper middle income          UMC
# 63                            East Asia & Pacific          EAS
# 142                     Late-demographic dividend          LTE
# 61    East Asia & Pacific (excluding high income)          EAP
# 230    East Asia & Pacific (IDA & IBRD countries)          TEA
# 240                       South Asia (IDA & IBRD)          TSA
# 204                                    South Asia          SAS
# ...

# %% [markdown]
# ## Linsepace Scatter Graph

# %%
colors_2020 = plt.cm.Blues(np.linspace(0.3, 1, 20))
x = np.arange(20)
y = np.random.rand(20)

plt.figure(figsize=(10, 6))
for i in range(20):
    plt.scatter(x[i], y[i], color=colors_2020[i], s=100)
    
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Scatter Plot with Blues Colormap')
plt. show()

# %%
colors_2010 = plt. cm.Greens(np.linspace(0.3, 1, 20))

x = np.arange(20)
y = np.random.rand(20)

plt.figure(figsize=(10, 6))
for i in range(20):
    plt.scatter(x[i], y[i], color=colors_2010[i], s=100)
    
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Scatter Plot with Greens Colormap') 
plt.show()

# %% [markdown]
# ## Examples for the population for the years 2010 and 2020

# %%
# Example population data for the years 2010 and 2020 (in millions)
countries = ['China', 'India', 'United States', 'Indonesia', 'Pakistan']
population_2010 = [1340, 1230, 309, 242, 184]
population_2020 = [1441, 1380, 331, 273, 220]

# Define the position of the bars on the x-axis
x = np. arange(len(countries)) # the label locations
width = 0.35 # the width of the bars

# Create a bar graph
fig, ax = plt.subplots(figsize=(12, 7))
bars1 = ax.bar(x - width/2, population_2010, width, label='2010', color='skyblue')
bars2 = ax.bar(x + width/2, population_2020, width, label='2020', color='pink')

#Add some text for labels, titles , and custom x-axis tick labels , etc.
ax.set_xlabel('Countries')
ax.set_ylabel('Population (in millions)')
ax.set_title('Population Comparison: 2010 vs 2020')
ax.set_xticks(x)
ax.set_xticklabels(countries)
ax.legend()

# Add a grid for better readability
ax.grid(True, linestyle='--', alpha=0.7)

# Function to add labels on the bars

# Add a grid for better readability
ax.grid(True, linestyle='--', alpha=0.7)

# Function to add labels on the bars
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax. annotate(f'{height}',
                     xy=(bar.get_x() + bar.get_width() / 2, height),
                     xytext=(0, 3), # 3 points vertical offset 
                     textcoords="offset points", 
                     ha='center', va='bottom')

# Add labels to the bars
add_labels(bars1)
add_labels(bars2)

# Show the plot
plt. show()

# %% [markdown]
# ## Population India VS Germany from the year 2010 to 2020

# %%
# Detine countries and years
countries = ['India', 'Germany']
years = ['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020']

# Example population data for India and Germany from 2010 to 2020 (in millions)
population_india = [1230, 1245, 1260, 1275, 1290, 1305, 1320, 1335, 1350, 1365, 1380]
population_germany = [81.8, 80.9, 80.5, 80.4, 80.3, 80.5, 80.7, 80.8, 81.0, 81.2, 81.3]

# Define the position of the bars on the x-axis
x = np.arange(len(years)) # the label locations
width = 0.35 # the width of the bars

# Create a bar graph
fig, ax = plt.subplots(figsize=(14, 8))
bars1 = ax.bar(x - width/2, population_india, width, label='India', color='skyblue')
bars2 = ax.bar(x + width/2, population_germany, width, label= 'Germany', color='purple')

# Add some text for labels, title, and custom x-axis tick labels, etc.
ax.set_xlabel ('Years')
ax.set_ylabel( 'Population (in millions)')
ax.set_title('Population Comparison: India vs Germany (2010-2020)')
ax.set_xticks(x)
ax.set_xticklabels (years)
ax. legend()

# Add a grid for better readability
ax.grid(True, linestyle='--', alpha=0.7)

# Function to add labels on the bars
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax. annotate(f'{height:.1f}',
                     xy=(bar.get_x() + bar.get_width() / 2, height),
                     xytext=(0, 3), # 3 points vertical offset 
                     textcoords="offset points", 
                     ha= 'center', va= 'bottom')
        
# Add labels to the bars
add_labels(bars1)
add_labels(bars2)

# Show the plot
plt.show()

# %% [markdown]
# ## Top 10 most populated countries 2010 vs 2020

# %%
# Extract relevant columns
population_data = df[['Country Name', '2010', '2020']]

# Drop rows with missing values
population_data = population_data.dropna()

# Convert population columns to numeric
population_data['2010'] = pd.to_numeric(population_data['2010'])
population_data['2020'] = pd.to_numeric(population_data['2020'])

# Get the top 10 most populated countries for each year
top_10_2010 = population_data.nlargest(10, '2010')
top_10_2020 = population_data.nlargest(10, '2020')

# Combine the top 10 lists and remove duplicates
top_countries = pd.concat([top_10_2010, top_10_2020]).drop_duplicates().reset_index(drop=True)
colors = sns.color_palette('muted')

# Plot the data
x = np.arange(len(top_countries['Country Name']))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(14, 8))
bars1 = ax.bar(x - width/2, top_countries['2010'], width, label='2010', color=colors[7])
bars2 = ax.bar(x + width/2, top_countries['2020'], width, label='2020', color=colors[6])

# Add some text for labels, title, and custom x-axis tick labels, etc.
ax.set_xlabel('Countries')
ax.set_ylabel('Population (in millions)')
ax.set_title('Top 10 Most Populated Countries: 2010 vs 2020')
ax.set_xticks(x)
ax.set_xticklabels(top_countries['Country Name'], rotation=45, ha='right')
ax.legend()

# Add a grid for better readability
ax.grid(True, linestyle='--', alpha=0.7)

# Function to add labels on the bars
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.1f}',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

# Add labels to the bars
add_labels(bars1)
add_labels(bars2)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Top 10 least populatd countries 2010 vs 2020

# %%
# Extract relevant columns
population_data = df[['Country Name', '2010', '2020']]

# Drop rows with missing values
population_data = population_data.dropna()

# Convert population columns to numeric
population_data['2010'] = pd.to_numeric(population_data['2010'])
population_data['2020'] = pd.to_numeric(population_data['2020'])

# Get the top 10 least populated countries for each year
bottom_10_2010 = population_data.nsmallest(10, '2010')
bottom_10_2020 = population_data.nsmallest(10, '2020')

# Combine the bottom 10 lists and remove duplicates
bottom_countries = pd.concat([bottom_10_2010, bottom_10_2020]).drop_duplicates().reset_index(drop=True)

# Set the aesthetic color palette
colors = sns.color_palette('muted')

# Plot the data
x = np.arange(len(bottom_countries['Country Name']))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(14, 8))

bars1 = ax.bar(x - width/2, bottom_countries['2010'], width, label='2010', color=colors[2])
bars2 = ax.bar(x + width/2, bottom_countries['2020'], width, label='2020', color=colors[3])

# Add some text for labels, title, and custom x-axis tick labels, etc.
ax.set_xlabel('Countries')
ax.set_ylabel('Population (in millions)')
ax.set_title('Top 10 Least Populated Countries: 2010 vs 2020')
ax.set_xticks(x)
ax.set_xticklabels(bottom_countries['Country Name'], rotation=45, ha='right')
ax.legend()

# Add a grid for better readability
ax.grid(True, linestyle='--', alpha=0.7)

# Function to add labels on the bars
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.1f}',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

# Add labels to the bars
add_labels(bars1)
add_labels(bars2)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Standard Deviation of Population Growth Rates 1960 to 2022

# %%
# Select relevant columns (Country Name and population data from 1960 to 2022)
population_data = df[['Country Name'] + [str(year) for year in range(1960, 2023)]]

# Calculate the year-over-year growth rate for each country, using fill_method=None
population_growth = population_data.set_index('Country Name').pct_change(axis=1, fill_method=None).dropna(axis=1, how='all')

# Calculate the standard deviation of growth rates for each country to measure consistency
growth_std_dev = population_growth.std(axis=1)

# Select the 5 countries with the lowest standard deviation in growth rates
consistent_growth_countries = growth_std_dev.nsmallest(5)

print(consistent_growth_countries)
# Out:
# Country Name
# Least developed countries: UN classification    0.001180
# Sub-Saharan Africa                              0.001264
# Sub-Saharan Africa (IDA & IBRD countries)       0.001264
# Sub-Saharan Africa (excluding high income)      0.001265
# Barbados                                        0.001332
# dtype: float64

# %%
# Select relevant columns (Country Name and population data from 1960 to 2022)
population_data = df[['Country Name'] + [str(year) for year in range(1960, 2023)]]

# Calculate the year-over-year growth rate for each country, using fill_method=None
population_growth = population_data.set_index('Country Name').pct_change(axis=1, fill_method=None).dropna(axis=1, how='all')

# Calculate the standard deviation of growth rates for each country to measure consistency
growth_std_dev = population_growth.std(axis=1)

# Select the 5 countries with the lowest standard deviation in growth rates
consistent_growth_countries = growth_std_dev.nsmallest(20)

# Plot a bar chart of the standard deviation of growth rates for the most consistent countries
plt.figure(figsize=(12, 8))
consistent_growth_countries.plot(kind='bar', edgecolor='black')
plt.title('Standard Deviation of Population Growth Rates (1960-2022)')
plt.xlabel('Country')
plt.ylabel('Standard Deviation of Growth Rates')
plt.xticks(rotation=45, ha='right')

# Annotate the bars with the exact standard deviation values
for index, value in enumerate(consistent_growth_countries):
    plt.text(index, value, f'{value:.6f}', ha='center', va='bottom')

plt.show()

# Print the 20 countries with the most consistent growth rates
print("20 Countries with the Most Consistent Population Growth:")
print(consistent_growth_countries)
# Out:
# 20 Countries with the Most Consistent Population Growth:
# Country Name
# Least developed countries: UN classification    0.001180
# Sub-Saharan Africa                              0.001264
# Sub-Saharan Africa (IDA & IBRD countries)       0.001264
# Sub-Saharan Africa (excluding high income)      0.001265
# Barbados                                        0.001332
# IDA only                                        0.001458
# Africa Eastern and Southern                     0.001558
# Fragile and conflict affected situations        0.001594
# Heavily indebted poor countries (HIPC)          0.001683
# Finland                                         0.001816
# IDA total                                       0.001911
# Senegal                                         0.001972
# Madagascar                                      0.002043
# Africa Western and Central                      0.002047
# Pre-demographic dividend                        0.002110
# ...

# %% [markdown]
# ## Top 20 populated countries in 2010 and 2020

# %%
# Extract the population data for 2010 and 2020
population_2010 = df[['Country Name', '2010']].dropna()
population_2020 = df[['Country Name', '2020']].dropna()

# Sort the population data and select the top 20 countries for each year
top_20_2010 = population_2010.nlargest(20, '2010').set_index('Country Name')
top_20_2020 = population_2020.nlargest(20, '2020').set_index('Country Name')

# Create side-by-side bar charts for the top 20 countries in 2010 and 2020
fig, axs = plt.subplots(1, 2, figsize=(16, 8))
colors = sns.color_palette("muted")

# Plot for 2010
axs[0].bar(top_20_2010.index, top_20_2010['2010'], color=colors[4], alpha=0.7)
axs[0].set_title('Top 20 Populated Countries in 2010')
axs[0].set_ylabel('Population')
axs[0].tick_params(axis='x', rotation=90)

# Plot for 2020
axs[1].bar(top_20_2020.index, top_20_2020['2020'], color=colors[5], alpha=0.7)
axs[1].set_title('Top 20 Populated Countries in 2020')
axs[1].set_ylabel('Population')
axs[1].tick_params(axis='x', rotation=90)

plt.tight_layout()
plt.show()
